# %%
# web scraping Tankathon's 2020 NBA Draft for player attributes and statistics 

import requests
# read webpage
r = requests.get('http://www.tankathon.com/big_board')

# %%
print(r.text[0:500])
# Out:
# <!DOCTYPE html><html lang="en"><head>
# <script>window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"9a7835ebc1","applicationID":"2231847","transactionName":"cg1cTUFaWVlXExcIB1gMHVtaUmpXXQBKAQ==","queueTime":8,"applicationTime":270,"agent":""}</script>
# <script>(window.NREUM||(NREUM={})).loader_config={licenseKey:"9a7835ebc1",applicationID:"2231847"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var i=n[t]={exp

# %%
from bs4 import BeautifulSoup
# read html
soup = BeautifulSoup(r.text, 'html.parser')

# %%
names_html = soup.find_all('div', attrs = {'class':'mock-row-name'})
names = []
for i in range(len(names_html)):
    names.append(names_html[i].text)
    print(names[i])
# Out:
# LaMelo Ball
# Onyeka Okongwu
# Killian Hayes
# James Wiseman
# Tyrese Haliburton
# Obi Toppin
# Anthony Edwards
# Deni Avdija
# RJ Hampton
# Aleksej Pokuševski
# Devin Vassell
# Josh Green
# Isaac Okoro
# Tyler Bey
# Jalen Smith
# Paul Reed
# Cole Anthony
# Saddiq Bey
# Kira Lewis Jr.
# Jahmi'us Ramsey
# Tyrese Maxey
# Nico Mannion
# Theo Maledon
# Aaron Nesmith
# Tre Jones
# Reggie Perry
# Vernon Carey Jr.
# Isaiah Stewart
# Tyrell Terry
# Cassius Stanley
# Killian Tillie
# Desmond Bane
# Leandro Bolmaro
# Xavier Tillman
# Patrick Williams
# Immanuel Quickley
# Daniel Oturu
# Devon Dotson
# Precious Achiuwa
# Joel Ayayi
# Jaden McDaniels
# Malachi Flynn
# Markus Howard
# Jordan Nwora
# Zeke Nnaji
# Elijah Hughes
# Cassius Winston
# Udoka Azubuike
# Payton Pritchard
# Robert Woodard II
# Jared Butler
# Isaiah Joe
# Grant Riller
# Corey Kispert
# Ashton Hagans
# Skylar Mays
# Kaleb Wesson
# Tres Tinkle
# Paul Eboua
# Nick Richards
# Myles Powell
# Trevelin Queen
# Trendon Watford
# Jay Scrubb
# Ayo Dosunmu
# Malcolm Cazalon
# Anfernee McLemore
# AJ Lawson
# Kahlil Whitney
# Jon Teske
# Charles Bassey
# Austin Wiley

# %%
school_position_html = soup.find_all('div', attrs = {'class': 'mock-row-school-position'})
positions = []
schools = []
for i in range(len(school_position_html)):
    line = str(school_position_html[i].text).split(' | ')
    positions.append(line[0])
    schools.append(line[1])
    print("%s, %s" % (positions[i], schools[i]))
# Out:
# PG, Illawarra
# PF/C, USC
# PG/SG, Ratiopharm Ulm
# C, Memphis
# PG, Iowa State
# PF, Dayton
# SG, Georgia
# SF, Maccabi Tel Aviv
# SG/PG, NZ Breakers
# PF, Olympiacos B
# SG/SF, Florida State
# SG, Arizona
# SF, Auburn
# SF, Colorado
# PF, Maryland
# PF, DePaul
# PG, North Carolina
# SF, Villanova
# PG, Alabama
# SG, Texas Tech
# SG, Kentucky
# PG, Arizona
# PG, ASVEL
# SF, Vanderbilt
# PG, Duke
# PF, Mississippi State
# C, Duke
# PF, Washington
# PG, Stanford
# SG, Duke
# PF/C, Gonzaga
# SG, TCU
# SG, FC Barcelona
# C, Michigan State
# PF, Florida State
# SG, Kentucky
# C, Minnesota
# PG, Kansas
# PF, Memphis
# PG/SG, Gonzaga
# SF, Washington
# PG, San Diego State
# PG, Marquette
# SF, Louisville
# C, Arizona
# SG/SF, Syracuse
# PG, Michigan State
# C, Kansas
# PG, Oregon
# SF, Mississippi State
# PG, Baylor
# SG, Arkansas
# PG/SG, Charleston
# SF, Gonzaga
# PG, Kentucky
# SG, LSU
# C, Ohio State
# SF, Oregon State
# PF, VL Pesaro
# C, Kentucky
# PG, Seton Hall
# SG, New Mexico State
# SF, LSU
# SG, John A. Logan
# PG/SG, Illinois
# SG, Leuven
# PF, Auburn
# SG, South Carolina
# SF, Kentucky
# C, Michigan
# C, Western Kentucky
# C, Auburn

# %%
height_weight_html = soup.find_all('div', attrs = {'class': 'section height-weight'})
heights = []
weights = []
for i in range(len(height_weight_html)):
    line = height_weight_html[i].contents
    height = line[0].text
    weight = line[1].text
    
    heights.append(height[0:-1])
    weights.append(weight)
    print("%s, %s" %(heights[i], weights[i]))
# Out:
# 6'7, 190 lbs
# 6'9, 245 lbs
# 6'5, 187 lbs
# 7'1, 237 lbs
# 6'5, 175 lbs
# 6'9, 220 lbs
# 6'5, 225 lbs
# 6'9, 215 lbs
# 6'5, 188 lbs
# 7'0, 201 lbs
# 6'7, 194 lbs
# 6'6, 206 lbs
# 6'6, 225 lbs
# 6'7, 216 lbs
# 6'10, 225 lbs
# 6'9, 220 lbs
# 6'3, 184 lbs
# 6'8, 216 lbs
# 6'3, 165 lbs
# 6'4, 195 lbs
# 6'3, 198 lbs
# 6'3, 179 lbs
# 6'4, 174 lbs
# 6'6, 213 lbs
# 6'2.5, 185 lbs
# 6'10, 250 lbs
# 6'10, 265 lbs
# 6'9, 245 lbs
# 6'1, 160 lbs
# 6'6, 193 lbs
# 6'10, 220 lbs
# 6'5, 215 lbs
# 6'7, 180 lbs
# 6'9, 245 lbs
# 6'8, 225 lbs
# 6'3, 188 lbs
# 6'10, 240 lbs
# 6'2, 179 lbs
# 6'9, 223 lbs
# 6'5, 180 lbs
# 6'10, 184 lbs
# 6'1, 185 lbs
# 5'11, 175 lbs
# 6'7.5, 220 lbs
# 6'11, 240 lbs
# 6'6, 215 lbs
# 6'1, 185 lbs
# 7'0, 274 lbs
# 6'2, 190 lbs
# 6'7, 230 lbs
# 6'3, 190 lbs
# 6'5, 180 lbs
# 6'3, 190 lbs
# 6'7, 220 lbs
# 6'3, 198 lbs
# 6'4, 205 lbs
# 6'9, 270 lbs
# 6'7, 225 lbs
# 6'8, 223 lbs
# 6'11, 247 lbs
# 6'2, 195 lbs
# 6'6, 190 lbs
# 6'9, 236 lbs
# 6'6, 200 lbs
# 6'5, 185 lbs
# 6'6, 186 lbs
# 6'7, 220 lbs
# 6'6, 178 lbs
# 6'8, 200 lbs
# 7'1, 260 lbs
# 6'10, 239 lbs
# 6'10, 249 lbs

# %%
year_age_html = soup.find_all('div', attrs = {'class': 'section year-age desktop'}) 
years = []
ages = []
for i in range(len(year_age_html)):
    line = year_age_html[i].contents
    
    years.append(line[0].text)
    ages.append(line[1].text)
    print("%s, %s" %(years[i], ages[i]))
# Out:
# International, 18.8 yrs
# Freshman, 19.5 yrs
# International, 18.9 yrs
# Freshman, 19.2 yrs
# Sophomore, 20.3 yrs
# Sophomore, 22.2 yrs
# Freshman, 18.8 yrs
# International, 19.4 yrs
# International, 19.3 yrs
# International, 18.4 yrs
# Sophomore, 19.8 yrs
# Freshman, 19.5 yrs
# Freshman, 19.4 yrs
# Junior, 22.3 yrs
# Sophomore, 20.2 yrs
# Junior, 20.9 yrs
# Freshman, 20.1 yrs
# Sophomore, 21.2 yrs
# Sophomore, 19.2 yrs
# Freshman, 18.9 yrs
# Freshman, 19.6 yrs
# Freshman, 19.2 yrs
# International, 18.9 yrs
# Sophomore, 20.6 yrs
# Sophomore, 20.4 yrs
# Sophomore, 20.2 yrs
# Freshman, 19.3 yrs
# Freshman, 19.0 yrs
# Freshman, 19.7 yrs
# Freshman, 20.8 yrs
# Senior, 22.2 yrs
# Senior, 21.9 yrs
# International, 19.7 yrs
# Junior, 21.4 yrs
# Freshman, 18.8 yrs
# Sophomore, 20.9 yrs
# Sophomore, 20.7 yrs
# Sophomore, 20.8 yrs
# Freshman, 20.7 yrs
# Sophomore, 20.2 yrs
# Freshman, 19.7 yrs
# Junior, 22.1 yrs
# Senior, 21.3 yrs
# Junior, 21.7 yrs
# Freshman, 19.4 yrs
# Junior, 22.2 yrs
# Senior, 22.3 yrs
# Senior, 20.7 yrs
# Senior, 22.3 yrs
# Sophomore, 20.7 yrs
# Sophomore, 20.7 yrs
# Sophomore, 20.9 yrs
# Senior, 23.3 yrs
# Junior, 21.3 yrs
# Sophomore, 20.9 yrs
# Senior, 22.6 yrs
# Junior, 20.8 yrs
# Senior, 24.0 yrs
# International, 20.3 yrs
# Junior, 22.5 yrs
# Senior, 22.9 yrs
# Senior, 23.3 yrs
# Freshman, 19.6 yrs
# Freshman, 19.8 yrs
# Sophomore, 20.4 yrs
# International, 18.8 yrs
# Senior, 21.9 yrs
# Sophomore, 19.9 yrs
# Freshman, 19.4 yrs
# Senior, 23.1 yrs
# Sophomore, 19.6 yrs
# Senior, 21.4 yrs

# %%
def scrapeStats(class_name):
    search = soup.find_all('div', attrs = {'class': class_name})
    
    ret = []
    for i in range(len(search)):
        line = search[i].contents
        classes = line[0].get('class')
        if 'stat-quality' not in classes:
            # todo: handle jay scrubb somehow
            if line[-1].text == 'pts':
                print(line)
                ret.append(line[0].text)
    print(len(ret))
    return ret

# %%
# # print(scrapeStats("stat pts"))
# scrapeStats("stat pts")

search = soup.find_all('div', attrs = {'class': 'stats-per-game'})
pts = []
reb = []
ast = []
blk = []
stl = []
for i in range(len(search)+1):
    if i < 63:
        line = search[i].contents
        pts_line = line[0].contents
        reb_line = line[1].contents
        ast_line = line[2].contents
        blk_line = line[3].contents
        stl_line = line[4].contents

        pts.append(pts_line[0].text)
        reb.append(reb_line[0].text)
        ast.append(ast_line[0].text)
        blk.append(blk_line[0].text)
        stl.append(stl_line[0].text)
        
    elif i == 63:
        # handle jay scrubb
        pts.append('20.2')
        reb.append('8.9')
        ast.append('1.5')
        blk.append('1.6')
        stl.append('1.1')
    elif i > 63:
        line = search[i-1].contents
        pts_line = line[0].contents
        reb_line = line[1].contents
        ast_line = line[2].contents
        blk_line = line[3].contents
        stl_line = line[4].contents

        pts.append(pts_line[0].text)
        reb.append(reb_line[0].text)
        ast.append(ast_line[0].text)
        blk.append(blk_line[0].text)
        stl.append(stl_line[0].text)

print(len(pts))
print(len(reb))
print(len(ast))
print(len(blk))
print(len(stl))
# Out:
# 72
# 72
# 72
# 72
# 72

# %% [markdown]
# for i in range(len(pts))

# %%
for i in range(len(pts)):
    print("(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)" %(names[i], positions[i], schools[i], heights[i], weights[i], years[i], ages[i], pts[i], 
                            reb[i], ast[i], blk[i], stl[i]))
# Out:
# (LaMelo Ball, PG, Illawarra , 6'7, 190 lbs, International, 18.8 yrs, 17.0, 7.6, 6.8, 0.1, 1.6)
# (Onyeka Okongwu, PF/C, USC , 6'9, 245 lbs, Freshman, 19.5 yrs, 16.2, 8.6, 1.1, 2.7, 1.2)
# (Killian Hayes, PG/SG, Ratiopharm Ulm , 6'5, 187 lbs, International, 18.9 yrs, 11.6, 2.8, 5.4, 0.3, 1.5)
# (James Wiseman, C, Memphis , 7'1, 237 lbs, Freshman, 19.2 yrs, 19.7, 10.7, 0.3, 3.0, 0.3)
# (Tyrese Haliburton, PG, Iowa State , 6'5, 175 lbs, Sophomore, 20.3 yrs, 15.2, 5.9, 6.5, 0.7, 2.5)
# (Obi Toppin, PF, Dayton , 6'9, 220 lbs, Sophomore, 22.2 yrs, 20.0, 7.5, 2.2, 1.2, 1.0)
# (Anthony Edwards, SG, Georgia , 6'5, 225 lbs, Freshman, 18.8 yrs, 19.1, 5.2, 2.8, 0.6, 1.3)
# (Deni Avdija, SF, Maccabi Tel Aviv , 6'9, 215 lbs, International, 19.4 yrs, 7.7, 4.1, 1.7, 0.6, 0.5)
# (RJ Hampton, SG/PG, NZ Breakers , 6'5, 188 lbs, International, 19.3 yrs, 8.8, 3.9, 2.4, 0.3, 1.1)
# (Aleksej Pokuševski, PF, Olympiacos B , 7'0, 201 lbs, International, 18.4 yrs, 9.9, 7.3, 2.8, 1.7, 1.2)
# (Devin Vassell, SG/SF, Florida State , 6'7, 194 lbs, Sophomore, 19.8 yrs, 12.7, 5.1, 1.6, 1.0, 1.4)
# (Josh Green, SG, Arizona , 6'6, 206 lbs, Freshman, 19.5 yrs, 12.0, 4.6, 2.6, 0.4, 1.5)
# (Isaac Okoro, SF, Auburn , 6'6, 225 lbs, Freshman, 19.4 yrs, 12.8, 4.4, 2.0, 0.9, 0.9)
# (Tyler Bey, SF, Colorado , 6'7, 216 lbs, Junior, 22.3 yrs, 13.8, 9.0, 1.5, 1.2, 1.5)
# (Jalen Smith, PF, Maryland , 6'10, 225 lbs, Sophomore, 20.2 yrs, 15.5, 10.5, 0.8, 2.4, 0.7)
# (Paul Reed, PF, DePaul , 6'9, 220 lbs, Junior, 20.9 yrs, 15.1, 10.7, 1.6, 2.6, 1.9)
# (Cole Anthony, PG, North Carolina , 6'3, 184 lbs, Freshman, 20.1 yrs, 18.5, 5.7, 4.0, 0.3, 1.3)
# (Saddiq Bey, SF, Villanova , 6'8, 216 lbs, Sophomore, 21.2 yrs, 16.1, 4.7, 2.4, 0.4, 0.8)
# (Kira Lewis Jr., PG, Alabama , 6'3, 165 lbs, Sophomore, 19.2 yrs, 18.5, 4.8, 5.2, 0.6, 1.8)
# (Jahmi'us Ramsey, SG, Texas Tech , 6'4, 195 lbs, Freshman, 18.9 yrs, 15.0, 4.0, 2.2, 0.7, 1.3)
# (Tyrese Maxey, SG, Kentucky , 6'3, 198 lbs, Freshman, 19.6 yrs, 14.0, 4.3, 3.2, 0.4, 0.9)
# (Nico Mannion, PG, Arizona , 6'3, 179 lbs, Freshman, 19.2 yrs, 14.0, 2.5, 5.3, 0.0, 1.2)
# (Theo Maledon, PG, ASVEL , 6'4, 174 lbs, International, 18.9 yrs, 7.3, 1.9, 2.7, 0.1, 0.5)
# (Aaron Nesmith, SF, Vanderbilt , 6'6, 213 lbs, Sophomore, 20.6 yrs, 23.0, 4.9, 0.9, 0.9, 1.4)
# (Tre Jones, PG, Duke , 6'2.5, 185 lbs, Sophomore, 20.4 yrs, 16.2, 4.2, 6.4, 0.3, 1.8)
# (Reggie Perry, PF, Mississippi State , 6'10, 250 lbs, Sophomore, 20.2 yrs, 17.4, 10.1, 2.3, 1.2, 0.8)
# (Vernon Carey Jr., C, Duke , 6'10, 265 lbs, Freshman, 19.3 yrs, 17.8, 8.8, 1.0, 1.6, 0.7)
# (Isaiah Stewart, PF, Washington , 6'9, 245 lbs, Freshman, 19.0 yrs, 17.0, 8.8, 0.8, 2.1, 0.5)
# (Tyrell Terry, PG, Stanford , 6'1, 160 lbs, Freshman, 19.7 yrs, 14.6, 4.5, 3.2, 0.1, 1.4)
# (Cassius Stanley, SG, Duke , 6'6, 193 lbs, Freshman, 20.8 yrs, 12.6, 4.9, 1.0, 0.7, 0.7)
# (Killian Tillie, PF/C, Gonzaga , 6'10, 220 lbs, Senior, 22.2 yrs, 13.6, 5.0, 1.9, 0.8, 1.0)
# (Desmond Bane, SG, TCU , 6'5, 215 lbs, Senior, 21.9 yrs, 16.6, 6.3, 3.9, 0.5, 1.5)
# (Leandro Bolmaro, SG, FC Barcelona , 6'7, 180 lbs, International, 19.7 yrs, 8.0, 1.7, 2.5, 0.1, 1.3)
# (Xavier Tillman, C, Michigan State , 6'9, 245 lbs, Junior, 21.4 yrs, 13.7, 10.3, 3.0, 2.1, 1.2)
# (Patrick Williams, PF, Florida State , 6'8, 225 lbs, Freshman, 18.8 yrs, 9.2, 4.0, 1.0, 1.0, 1.0)
# (Immanuel Quickley, SG, Kentucky , 6'3, 188 lbs, Sophomore, 20.9 yrs, 16.1, 4.2, 1.9, 0.1, 0.9)
# (Daniel Oturu, C, Minnesota , 6'10, 240 lbs, Sophomore, 20.7 yrs, 20.1, 11.3, 1.1, 2.5, 0.5)
# (Devon Dotson, PG, Kansas , 6'2, 179 lbs, Sophomore, 20.8 yrs, 18.1, 4.1, 4.0, 0.1, 2.1)
# (Precious Achiuwa, PF, Memphis , 6'9, 223 lbs, Freshman, 20.7 yrs, 15.8, 10.8, 1.0, 1.9, 1.1)
# (Joel Ayayi, PG/SG, Gonzaga , 6'5, 180 lbs, Sophomore, 20.2 yrs, 10.6, 6.3, 3.2, 0.2, 1.3)
# (Jaden McDaniels, SF, Washington , 6'10, 184 lbs, Freshman, 19.7 yrs, 13.0, 5.8, 2.1, 1.4, 0.8)
# (Malachi Flynn, PG, San Diego State , 6'1, 185 lbs, Junior, 22.1 yrs, 17.6, 4.5, 5.1, 0.1, 1.8)
# (Markus Howard, PG, Marquette , 5'11, 175 lbs, Senior, 21.3 yrs, 27.8, 3.5, 3.3, 0.0, 0.9)
# (Jordan Nwora, SF, Louisville , 6'7.5, 220 lbs, Junior, 21.7 yrs, 18.0, 7.7, 1.3, 0.3, 0.7)
# (Zeke Nnaji, C, Arizona , 6'11, 240 lbs, Freshman, 19.4 yrs, 16.1, 8.6, 0.8, 0.9, 0.7)
# (Elijah Hughes, SG/SF, Syracuse , 6'6, 215 lbs, Junior, 22.2 yrs, 19.0, 4.9, 3.4, 0.8, 1.2)
# (Cassius Winston, PG, Michigan State , 6'1, 185 lbs, Senior, 22.3 yrs, 18.6, 2.5, 5.9, 0.0, 1.2)
# (Udoka Azubuike, C, Kansas , 7'0, 274 lbs, Senior, 20.7 yrs, 13.7, 10.5, 0.9, 2.6, 0.5)
# (Payton Pritchard, PG, Oregon , 6'2, 190 lbs, Senior, 22.3 yrs, 20.5, 4.3, 5.5, 0.0, 1.5)
# (Robert Woodard II, SF, Mississippi State , 6'7, 230 lbs, Sophomore, 20.7 yrs, 11.4, 6.5, 1.3, 1.0, 1.1)
# (Jared Butler, PG, Baylor , 6'3, 190 lbs, Sophomore, 20.7 yrs, 16.0, 3.2, 3.1, 0.1, 1.6)
# (Isaiah Joe, SG, Arkansas , 6'5, 180 lbs, Sophomore, 20.9 yrs, 16.9, 4.1, 1.7, 0.3, 1.4)
# (Grant Riller, PG/SG, Charleston , 6'3, 190 lbs, Senior, 23.3 yrs, 21.9, 5.1, 3.9, 0.3, 1.6)
# (Corey Kispert, SF, Gonzaga , 6'7, 220 lbs, Junior, 21.3 yrs, 13.9, 4.0, 2.1, 0.4, 0.9)
# (Ashton Hagans, PG, Kentucky , 6'3, 198 lbs, Sophomore, 20.9 yrs, 11.5, 3.9, 6.4, 0.2, 1.9)
# (Skylar Mays, SG, LSU , 6'4, 205 lbs, Senior, 22.6 yrs, 16.7, 5.0, 3.2, 0.2, 1.8)
# (Kaleb Wesson, C, Ohio State , 6'9, 270 lbs, Junior, 20.8 yrs, 14.0, 9.3, 1.9, 1.0, 0.7)
# (Tres Tinkle, SF, Oregon State , 6'7, 225 lbs, Senior, 24.0 yrs, 18.5, 6.8, 3.2, 0.5, 1.7)
# (Paul Eboua, PF, VL Pesaro , 6'8, 223 lbs, International, 20.3 yrs, 7.4, 5.3, 0.8, 0.7, 0.7)
# (Nick Richards, C, Kentucky , 6'11, 247 lbs, Junior, 22.5 yrs, 14.0, 7.8, 0.2, 2.1, 0.1)
# (Myles Powell, PG, Seton Hall , 6'2, 195 lbs, Senior, 22.9 yrs, 21.0, 4.3, 2.9, 0.2, 1.2)
# (Trevelin Queen, SG, New Mexico State , 6'6, 190 lbs, Senior, 23.3 yrs, 13.2, 5.2, 2.4, 0.3, 1.7)
# (Trendon Watford, SF, LSU , 6'9, 236 lbs, Freshman, 19.6 yrs, 13.6, 7.2, 1.7, 0.7, 0.9)
# (Jay Scrubb, SG, John A. Logan , 6'6, 200 lbs, Freshman, 19.8 yrs, 20.2, 8.9, 1.5, 1.6, 1.1)
# (Ayo Dosunmu, PG/SG, Illinois , 6'5, 185 lbs, Sophomore, 20.4 yrs, 16.6, 4.3, 3.3, 0.2, 0.8)
# (Malcolm Cazalon, SG, Leuven , 6'6, 186 lbs, International, 18.8 yrs, 6.0, 2.6, 1.4, 0.1, 0.5)
# (Anfernee McLemore, PF, Auburn , 6'7, 220 lbs, Senior, 21.9 yrs, 6.8, 4.4, 0.4, 1.1, 0.7)
# (AJ Lawson, SG, South Carolina , 6'6, 178 lbs, Sophomore, 19.9 yrs, 13.4, 3.7, 1.9, 0.1, 1.2)
# (Kahlil Whitney, SF, Kentucky , 6'8, 200 lbs, Freshman, 19.4 yrs, 3.3, 1.7, 0.4, 0.2, 0.3)
# (Jon Teske, C, Michigan , 7'1, 260 lbs, Senior, 23.1 yrs, 11.6, 6.7, 1.1, 1.8, 1.0)
# (Charles Bassey, C, Western Kentucky , 6'10, 239 lbs, Sophomore, 19.6 yrs, 15.3, 9.2, 1.3, 1.6, 0.8)
# (Austin Wiley, C, Auburn , 6'10, 249 lbs, Senior, 21.4 yrs, 10.6, 9.3, 0.5, 1.6, 0.5)
